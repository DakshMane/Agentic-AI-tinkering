# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool
from typing import Dict , Any 
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query : str) -> Dict[str , Any] : 
    """Search the web for information"""

    return tavily_client.search(query=query)

web_search.invoke("What is 1 USD in rupees")
# Out:
# {'query': 'What is 1 USD in rupees',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.riamoneytransfer.com/en-us/rates-conversion?From=USD&To=INR&Amount=1',
#    'title': 'US Dollar to Indian Rupee Exchange Rate',
#    'content': '# 1.00 US Dollar to Indian Rupee today\n\nConvert USD to INR at the current exchange rate\n\nAmount\n\nConverted To\n\n1.00 USD = 95.65633169 INR\n\nSend Money\n\nWe use the mid-market rate for reference only. Login to see actual send rates.\n\n## USD to INR exchange rates today\n\nUSD\n\nUSD\n\nINR\n\nINR\n\n1 USD95.65633 INR\n\n5 USD478.28166 INR\n\n25 USD2,391.40829 INR\n\n50 USD4,782.81658 INR\n\n100 USD9,565.63317 INR\n\n500 USD47,828.16585 INR\n\n1,000 USD95,656.33169 INR\n\n10,000 USD956,563.31695 INR [...] ### Convert US Dollar to Indian Rupee\n\nUSD\n\nUSD\n\nINR\n\nINR\n\n1 USD95.65633 INR\n\n5 USD478.28166 INR\n\n25 USD2,391.40829 INR\n\n50 USD4,782.81658 INR\n\n100 USD9,565.63317 INR\n\n500 USD47,828.16585 INR\n\n1,000 USD95,656.33169 INR\n\n10,000 USD956,563.31695 INR\n\n### Convert Indian Rupee to US Dollar\n\nINR\n\nINR\n\nUSD\n\nUSD\n\n1 INR0.01045 USD\n\n5 INR0.05227 USD\n\n25 INR0.26135 USD\n\n50 INR0.52270 USD\n\n100 INR1.04541 USD\n\n500 INR5.22705 USD\n\n1,000 INR10.45409 USD\n\n10,000 INR104.54091 USD [...] US flag\n\n  Easy to use and great exchange rates\n MM\n\n  ES flag\n\n  Transfers are quick and secure\n\n EG\n\n  CL flag\n\n  Excellent, fast and reliable\n CC\n\n  CA flag\n\n  It was easy to send money\n EC\n\n  US flag\n\n  Great service\n BD\n\n  NO flag\n\n  Very easy and quick to send money through Ria\n MA\n\n  CH flag\n\n  Fast, simple and efficient. Thanks Ria\n GC\n\n  US flag\n\n  Easy to use and great exchange rates\n MM\n\n  ES flag\n\n  Transfers are quick and secure\n\n AB\n\n  AU flag',
#    'score': 0.90810597,
#    'raw_content': None},
#   {'url': 'https://www.xe.com/en-us/currencyconverter/convert?Amount=1&From=USD&To=INR',
#    'title': '1 USD to INR - US Dollars to Indian Rupees Exchange Rate',
#    'content': "### How much is 1 USD in INR?\n\n1 USD equals 95.85 INR using the current mid-market exchange rate of ₹95.8563. If you're looking to send 1 USD to INR, check if Xe could save you money on your transfer. Get a live quote on our send money page and see the full price upfront.\n\n### How do I convert currencies?\n\nTo convert currencies, visit the top our Currency Converter, select your preferred currency pair, enter your amount, and view the live mid-market rate.\n\n### Can I set rate alerts with Xe? [...] us\n\n# 1 USD to INR - Convert US Dollars to Indian Rupees\n\nXe currency converter\n\nFrom\n\nUSD\n\nTo\n\nINR\n\n1.00 USD = 95.85631158 INR\n\nMid-market rate at 09:32 UTC\n\nWe use the mid-market rate for our Converter. This is for informational purposes only. You won’t receive this rate when sending money. Login to view send rates\n\nDid you know you can send money abroad with Xe?\n\nXE Logo\n\n## USD to INR exchange rates today\n\n#### Convert US Dollar to Indian Rupee\n\nRate information of USD/INR currency pair [...] See your 1 USD in motion. Our live USD to INR chart tracks 12 months of real-time, mid-market rates and shows exactly how much your money was worth at any point in time. Want to know when the rate moves in your favor? Set a rate alert and we’ll let you know when it hits your target.\n\n1 USD = 95.8563 INR\n\nJul 27, 2026, 09:32 UTC\n\n### USD to INR Chart\n\n### Compare and save",
#    'score': 0.90791017,
#    'raw_content': None},
#   {'url': 'https://www.revolut.com/en-US/currency-converter/convert-usd-to-inr-exchange-rate?amount=1',
#    'title': 'Convert 1 USD to INR | US Dollars to Indian Rupees Exchange Rates',
#    'content': 'No fees$0.00\n\nGet startedExchange rates are dynamic. Always remember to check the applicable rate in-app before carrying out your exchange\n\nExchange and transfer fees, fair usage limits, and Terms and Conditions apply.\n\n   140+ countries and regions supported\n   75+ million global customers and counting\n   Trusted with $15+ billion in deposits\n\nHow much is 1 USD worth in INR?\n\n## 1 USD to INR live exchange rates\n\n## 1 USD = 95.8375 INR\n\n₹9.0200 X 10.39 % [...] | Image 4: USUSD | Image 5INR |\n --- |\n| 1 USD | 95.66 INR |\n| 10 USD | 956.66 INR |\n| 20 USD | 1,913.32 INR |\n| 50 USD | 4,783.30 INR |\n| 100 USD | 9,566.61 INR |\n| 250 USD | 23,916.54 INR |\n| 300 USD | 28,699.85 INR |\n| 500 USD | 47,833.08 INR |\n| 1,000 USD | 95,759.51 INR |\n| 2,000 USD | 191,519.02 INR |\n| 5,000 USD | 478,797.55 INR |\n| 10,000 USD | 957,595.11 INR | [...] | Image 6INR | Image 7: USUSD |\n --- |\n| 1 INR | 0.01 USD |\n| 10 INR | 0.10 USD |\n| 20 INR | 0.20 USD |\n| 50 INR | 0.52 USD |\n| 100 INR | 1.04 USD |\n| 250 INR | 2.60 USD |\n| 300 INR | 3.12 USD |\n| 500 INR | 5.20 USD |\n| 1,000 INR | 10.41 USD |\n| 2,000 INR | 20.83 USD |\n| 5,000 INR | 52.08 USD |\n| 10,000 INR | 104.16 USD |\n\nAlthough we update our data continuously, exchange rates are always changing due to market fluctuations. Check the current rate in-app before you convert or send.',
#    'score': 0.8660535,
#    'raw_content': None},
#   {'url': 'https://www.westernunion.com/us/en/currency-converter/usd-to-inr-rate.html',
#    'title': 'USD to INR | Convert US Dollar to Indian Rupee',
#    'content': 'FX: 1.00 USD –   Exchange Rates and Fees shown are estimates, vary by a number of factors including payment and payout methods, and are subject to change. To check current rates and other options, simply click “Send money”.\u200b  X Fee:\n\nSend money now\n\nBe informed. Be aware. Protect yourself from fraud\n\nBe informed. Be aware.\n\nProtect yourself from fraud\n\nWe are committed to keeping your data secured\n\nSend money to 200+ countries or territories online or in-store [...] We move money from the United States of America to over 200 countries and territories. Just enter the USD amount to be converted to INR.\n\n## USD vs INR information\n\nUSD – US Dollar\n\nThe US Dollar is the official currency of United States of America. The currency code for the US Dollar is USD.\n\nINR – Indian Rupee\n\nThe Indian Rupee is the official currency of India. The currency code for the Indian Rupee is INR. [...] | 500 USD Exchange Rates shown are estimates, vary by a number of factors including payment and payout methods, and are subject to change. | INR |\n| 1000 USD Exchange Rates shown are estimates, vary by a number of factors including payment and payout methods, and are subject to change. | INR |\n| 2000 USD Exchange Rates shown are estimates, vary by a number of factors including payment and payout methods, and are subject to change. | INR |',
#    'score': 0.79883134,
#    'raw_content': None},
#   {'url': 'https://www.remitly.com/us/en/currency-converter/usd-to-inr-rate',
#    'title': 'USD to INR Exchange Rates - Convert US dollars to Indian rupees | Remitly',
#    'content': "Welcome offer\n\n# USD to INR\n\n## Remitly offers dependable exchange rates for USD to INR with no hidden fees. Join today and get a promotional rate of 95.65 INR to 1 USD on your first money transfer.\n\nOr select an amount\n\nININR\n\nFee\n\n-\n\nTotal\n\n-\n\nGet this rate\n\nHDFC Bank\n\nState Bank of India (SBI)\n\nFederal Bank\n\nand more [...] | Send Amount (USD) | Fee |\n --- |\n| Below $1,000 | $3.99 |\n| $1,000 or more | $0 |\n\nNo fees on your first transfer with Remitly. New customers only. One per customer. Limited time offer. See Terms and Conditions\u2060 (opens in new window) for details.\n\n## What affects the exchange rate for US dollars to Indian rupees?\n\nMany factors can determine exchange rates, including:\n\n### Central banks\n\nThe interest rate set by a country's central bank can affect foreign investment, impacting currency demand [...] and more\n\nNew customers only. One per customer. Limited time offer. Any rates shown are subject to change. Promotional FX rate applies to first 6,000.00 USD sent. If you are sending over 6,000.00 USD, the non-promotional FX rate shown applies when you pay by Bank account or Remitly Wallet. See Terms and Conditions\u2060 (opens in new window) for details.",
#    'score': 0.783542,
#    'raw_content': None}],
#  'response_time': 1.18,
#  'request_id': 'db147369-1314-4a52-9e8c-ce7186319412'}

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.chat_models import init_chat_model
model = init_chat_model(model="gemini-2.5-flash" , model_provider="google_genai" ,
                        temperature= 1.0 
                        )

agent = create_agent(
    model=model  , 
    tools=[web_search] , 
   
)

question = HumanMessage(content="What is 1 USD in rupees")

response = agent.invoke({
    "messages" : [question]
})

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is 1 USD in rupees', additional_kwargs={}, response_metadata={}, id='bfe2a9bb-0955-4793-bf74-22d589061ac0'),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'web_search', 'arguments': '{"query": "1 USD to INR"}'}, '__gemini_function_call_thought_signatures__': {'b803ca86-c05e-4e2a-9da4-df010b3f9fda': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fbebf-af65-7213-9496-d8f378dab433-0', tool_calls=[{'name': 'web_search', 'args': {'query': '1 USD to INR'}, 'id': 'b803ca86-c05e-4e2a-9da4-df010b3f9fda', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 45, 'output_tokens': 63, 'total_tokens': 108, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 45}}),
#  ToolMessage(content='{"query": "1 USD to INR", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.xe.com/en-us/currencyconverter/convert?Amount=1&From=USD&To=INR", "title": "1 USD to INR - US Dollars to Indian Rupees Exchange Rate", "content": "### How much is 1 USD in INR?\\n\\n1 USD equals 95.85 INR using the current mid-market exchange rate of ₹95.8563. If you\'re looking to send 1 USD to INR, check if Xe could save you money on your transfer. Get a live quote on our send money page and see the full price upfront.\\n\\n### How do I convert currencies?\\n\\nTo convert currencies, visit the top our Currency Converter, select your preferred currency pair, enter your amount, and view the live mid-market rate.\\n\\n### Can I set rate alerts with Xe? [...] us\\n\\n# 1 USD to INR - Convert US Dollars to Indian Rupees\\n\\nXe currency converter\\n\\nFrom\\n\\nUSD\\n\\nTo\\n\\nINR\\n\\n1.00 USD = 95.85631158 INR\\n\\nMid-market rate at 09:32 UTC\\n\\nWe use the mid-market rate for our Converter. This is for informational purposes only. You won’t receive this rate when sending money. Login to view send rates\\n\\nDid you know you can send money abroad with Xe?\\n\\nXE Logo\\n\\n## USD to INR exchange rates today\\n\\n#### Convert US Dollar to Indian Rupee\\n\\nRate information of USD/INR currency pair [...] | inr Indian RupeeINR | usd US DollarUSD |\\n --- |\\n| 1 INR | 0.0104323 USD |\\n| 5 INR | 0.0521614 USD |\\n| 10 INR | 0.104323 USD |\\n| 25 INR | 0.260807 USD |\\n| 50 INR | 0.521614 USD |\\n| 100 INR | 1.04323 USD |\\n| 500 INR | 5.21614 USD |\\n| 1,000 INR | 10.4323 USD |\\n| 5,000 INR | 52.1614 USD |\\n| 10,000 INR | 104.323 USD |\\n\\ninr\\nusd\\n\\n### USD to INR chart", "score": 0.9485422, "raw_content": null}, {"url": "https://www.revolut.com/en-US/currency-converter/convert-usd-to-inr-exchange-rate?amount=1", "title": "Convert 1 USD to INR | US Dollars to Indian Rupees Exchange Rates", "content": "| Image 4: USUSD | Image 5INR |\\n --- |\\n| 1 USD | 95.66 INR |\\n| 10 USD | 956.66 INR |\\n| 20 USD | 1,913.32 INR |\\n| 50 USD | 4,783.30 INR |\\n| 100 USD | 9,566.61 INR |\\n| 250 USD | 23,916.54 INR |\\n| 300 USD | 28,699.85 INR |\\n| 500 USD | 47,833.08 INR |\\n| 1,000 USD | 95,759.51 INR |\\n| 2,000 USD | 191,519.02 INR |\\n| 5,000 USD | 478,797.55 INR |\\n| 10,000 USD | 957,595.11 INR | [...] | Image 6INR | Image 7: USUSD |\\n --- |\\n| 1 INR | 0.01 USD |\\n| 10 INR | 0.10 USD |\\n| 20 INR | 0.20 USD |\\n| 50 INR | 0.52 USD |\\n| 100 INR | 1.04 USD |\\n| 250 INR | 2.60 USD |\\n| 300 INR | 3.12 USD |\\n| 500 INR | 5.20 USD |\\n| 1,000 INR | 10.41 USD |\\n| 2,000 INR | 20.83 USD |\\n| 5,000 INR | 52.08 USD |\\n| 10,000 INR | 104.16 USD |\\n\\nAlthough we update our data continuously, exchange rates are always changing due to market fluctuations. Check the current rate in-app before you convert or send. [...] No fees$0.00\\n\\nGet startedExchange rates are dynamic. Always remember to check the applicable rate in-app before carrying out your exchange\\n\\nExchange and transfer fees, fair usage limits, and Terms and Conditions apply.\\n\\n   140+ countries and regions supported\\n   75+ million global customers and counting\\n   Trusted with $15+ billion in deposits\\n\\nHow much is 1 USD worth in INR?\\n\\n## 1 USD to INR live exchange rates\\n\\n## 1 USD = 95.8375 INR\\n\\n₹9.0200 X 10.39 %", "score": 0.93911994, "raw_content": null}, {"url": "https://www.riamoneytransfer.com/en-us/rates-conversion?From=USD&To=INR&Amount=1", "title": "US Dollar to Indian Rupee Exchange Rate", "content": "# 1.00 US Dollar to Indian Rupee today\\n\\nConvert USD to INR at the current exchange rate\\n\\nAmount\\n\\nConverted To\\n\\n1.00 USD = 95.65633169 INR\\n\\nSend Money\\n\\nWe use the mid-market rate for reference only. Login to see actual send rates.\\n\\n## USD to INR exchange rates today\\n\\nUSD\\n\\nUSD\\n\\nINR\\n\\nINR\\n\\n1 USD95.65633 INR\\n\\n5 USD478.28166 INR\\n\\n25 USD2,391.40829  ...
#  AIMessage(content=[{'type': 'text', 'text': '1 USD is approximately 95.86 Indian Rupees.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fbebf-bc1d-7901-8f4b-148d5df664c1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3430, 'output_tokens': 167, 'total_tokens': 3597, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 154}})]
