# %%
from dotenv import load_dotenv
load_dotenv()
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gemini-2.5-flash" , model_provider="google_genai" ,
                        temperature= 1.0 
                        )

response = model.invoke("What is capital of Moon ")

print(response.content)
# Out:
# The Moon does not have a capital.
#
# Here's why:
# *   **Not a Political Entity:** The Moon is a celestial body, not a country, state, or any kind of political entity that would have a government or need a capital city.
# *   **No Permanent Settlements (Yet):** While humans have visited the Moon (Apollo missions) and there are plans for future bases (like Artemis), there are no permanent human cities or settlements there. There is no native civilization.
#
# Therefore, without a government or a population to govern, there's no need for a capital.

# %%
from langchain.agents import create_agent 

from langchain_core.messages import HumanMessage , AIMessage
from pprint import pprint

agent = create_agent(model=model , system_prompt="You are a expert helper assistant")


response = agent.invoke({
    "messages" : [HumanMessage(content="What is capital of Moon ? ")]
})

pprint(response['messages'][-1].content)

# %%
from langchain.agents import create_agent 

from langchain_core.messages import HumanMessage , AIMessage
from pprint import pprint
agent = create_agent(model=model , system_prompt="You are a expert helper assistant")

response = agent.invoke({
    "messages" : [HumanMessage(content="What is capital of Moon ? ") , 
                  AIMessage(content="The capital of Moon is Luna ")  , 
                  HumanMessage(content="Interesting , tell me more about Luna ")] 
})

pprint(response['messages'][-1].content)
# Out:
# ("Ah, that's where the interesting part comes in! While I previously said "
#  '"Luna" as a sort of playful answer, it\'s important to clarify:\n'
#  '\n'
#  '**The Moon does not actually have a capital city, or any cities at all, in '
#  "the real world.** It's an uninhabited celestial body.\n"
#  '\n'
#  'However, "Luna" is a fascinating and very popular concept in science fiction '
#  'and general parlance when discussing the Moon:\n'
#  '\n'
#  '1.  **"Luna" is the Latin word for Moon.** This is why many terms related to '
#  'the Moon (like "lunar eclipse," "lunar module") use this root. It\'s also '
#  'the name of the Roman goddess of the Moon.\n'
#  '\n'
#  '2.  **In science fiction, "Luna" is a very common name for a hypothetical '
#  'future city, colony, or even the Moon itself.**\n'
#  "    *   **Why it's popular:** It's short, elegant, historically linked to "
#  'the Moon, and sounds futuristic.\n'
#  '    *   **Concept:** If humanity were to establish a permanent, '
#  'self-sustaining base or a series of interconnected settlements on the Moon, '
#  'one of them might very well be named "Luna" or become its de facto '
#  '"capital."\n'
#  '\n'
#  '3.  **What a fictional "Luna" might entail:**\n'
#  '    *   **Location:** Often envisioned in strategic locations like the lunar '
#  'poles (for access to water ice) or in vast lava tubes (for natural radiation '
#  'shielding and stable temperatures).\n'
#  '    *   **Structure:** It would likely be subterranean, shielded from cosmic '
#  'radiation and micrometeoroids, with biodomes or artificial environments for '
#  'living and growing food.\n'
#  '    *   **Purpose:** A hub for scientific research, resource extraction '
#  '(like Helium-3 for fusion power), space tourism, or even a staging point for '
#  'further deep-space missions.\n'
#  '    *   **Economy:** Could involve lunar mining, advanced manufacturing in '
#  'low-gravity vacuum, research facilities, and services for a growing lunar '
#  'population.\n'
#  '\n'
#  '**In short:** When you hear "Luna" in the context of a Moon city or capital, '
#  "it's almost always a reference to a future, theoretical, or fictional human "
#  'settlement, borrowing from the ancient name for our closest celestial '
#  "neighbor. It represents humanity's dreams of expanding beyond Earth.")

# %% [markdown]
# ## STREAMING OUTPUTS  ....

# %%
from langchain.agents import create_agent 

from langchain_core.messages import HumanMessage , AIMessage
from pprint import pprint
agent = create_agent(model=model , system_prompt="You are a expert helper assistant")


for token , metadata in agent.stream({
    "messages" : [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]
} , stream_mode="messages") :

     if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Ah, Luna City! A magnificent dream, a testament to humanity's ambition, and a staple of science fiction for decades. Since it doesn't *currently* exist (yet!), let's paint a picture of what Luna City *could be* or *often is depicted as* in various speculative visions and fictional universes.
#
# Imagine a future where humanity has taken its first truly permanent steps off Earth.
#
# ---
#
# ## Luna City: The Capital of the Moon
#
# **Conception & Purpose:**
# Luna City isn't just a research outpost; it's envisioned as a true extraterrestrial metropolis, a vibrant center of human activity, culture, and industry. Its primary purposes would be multifaceted:
# *   **Scientific Research:** A prime location for astronomical observatories free from Earth's atmospheric distortion, geological studies of the Moon, and experiments in low-gravity environments.
# *   **Resource Extraction:** Tapping into lunar resources like Helium-3 (for fusion power), water ice (for propellant and life support), rare earth metals, and construction materials (regolith).
# *   **Spaceport & Gateway:** A crucial staging post for missions deeper into the solar system, benefiting from the Moon's low gravity for launching spacecraft.
# *   **Tourism:** An unparalleled destination for those seeking a truly alien experience, with breathtaking views of Earth.
# *   **Industry & Manufacturing:** Utilizing lunar resources to build and repair spacecraft, produce specialized materials, and even engage in zero-G manufacturing.
# *   **Permanent Habitation:** A new home for a diverse population, forging a distinct lunar culture.
#
# **Location:**
# While many locations are proposed, popular choices for Luna City often include:
# *   **Polar Craters (e.g., Shackleton Crater):** The rims offer near-constant sunlight for power, while the permanently shadowed interiors contain valuable water ice. This makes them ideal for self-sufficiency.
# *   **Mare Tranquillitatis (Sea of Tranquility):** Historically significant (Apollo 11 landing site), relatively flat, and good for initial expansion.
# *   **Lava Tubes:** Natural underground tunnels offering inherent shielding from radiation and micrometeorites, and stable temperatures.
#
# **Architecture & Design:**
# Luna City would be a marvel of engineering, built to withstand the harsh lunar environment:
# *   **Underground & Sub-Surface:** Much of the city would be built beneath the regolith (lunar dust and soil) for protection against solar radiation, cosmic rays, and micrometeoroids, as well as maintaining stable temperatures. These subterranean levels would house residences, commercial districts, industrial facilities, and transport networks.
# *   **Domes & Pressurized Modules:** On the surface, pressurized domes, made of advanced transparent materials (perhaps reinforced with regolith layers), would offer stunning views of the lunar landscape and Earth. These might house parks, public squares, observatories, or specialized facilities. Modular habitats, delivered from Earth or manufactured locally, would be interconnected.
# *   **Lava Tube Cities:** If built in lava tubes, the city could be a sprawling, protected network within natural caverns, with artificial lighting mimicking Earth's cycles.
# *   **Regolith Construction:** Local lunar regolith would be a primary building material, sintered or mixed with binders to create bricks, concrete, and shielding.
# *   **Advanced Life Support:** Closed-loop systems for air and water recycling would be paramount. Hydroponic and aeroponic farms would provide fresh food, integrating seamlessly into the city's structure.
#
# **Life & Society:**
# Life in Luna City would be unique and transformative:
# *   **Low-Gravity Living:** Daily life would be adapted to 1/6th Earth gravity, influencing everything from architecture (taller, lighter structures) to sports and movement. People might develop distinct gaits or even "fly" through large spaces.
# *   **Lunar Culture:** A new culture would emerge, blending influences from Earth's diverse nations but with a strong identity rooted in lunar existence. A focus on sustainability, community, and scientific endeavor would be prominent.
# *   **Earth-Moon Connection:** High-speed communication links would connect Luna City residents with Earth, allowing for virtual travel, remote work, and keeping in touch with loved ones.
# *   **Education & Healthcare:** Specialized education focusing on space sciences, engineering, and lunar living. Healthcare would be adapted to low-G effects on the human body (bone density, muscle mass).
# *   **Leisure & Recreation:** Low-gravity sports (lunar basketball, gymnastics), virtual reality environments, communal gardens, and observation decks offering views of Earthrise/Earthset.
#
# **Economy & Governance:**
# *   **Diverse Economy:** Driven by science, tourism, resource extraction, manufacturing, and advanced research.
# *   **International Cooperation:** Likely founded and governed by an international consortium (like a future UN Space Agency or independent Lunar Authority) to ensure equitable access and peaceful development.
# *   **Independent Governance:** As the city grows, it might develop its own distinct legal framework and even move towards greater autonomy from Earth.
# *   **Currency:** Could use Earth-based currencies, or develop its own digital or resource-backed lunar currency.
#
# **Challenges:**
# Despite its allure, Luna City would face immense challenges:
# *   **Radiation:** Constant threat from solar flares and cosmic rays, requiring robust shielding.
# *   **Dust (Regolith):** Fine, abrasive, and electrically charged lunar dust is a pervasive nuisance, damaging equipment and potentially impacting health.
# *   **Psychological Impact:** Isolation, confinement, and the alien environment could take a toll on mental health.
# *   **Resource Management:** Extremely efficient use and recycling of all resources (water, air, energy, materials) are critical.
# *   **Dependence on Earth:** Initially, heavy reliance on Earth for advanced components and personnel.
# *   **Maintaining Earth-like Environment:** The constant battle to maintain breathable atmosphere, stable temperature, and adequate protection.
#
# **The Dream:**
# Luna City represents humanity's next great leap – not just to visit, but to *live* off-world. It's a symbol of our species' drive to explore, innovate, and expand our horizons beyond our cradle planet, establishing the first permanent foothold in the vastness of space. It would be a true capital, not just of the Moon, but perhaps of a new era of human civilization.
