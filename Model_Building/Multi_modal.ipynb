# %% [markdown]
# Image Input

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model
from langchain.agents import create_agent


model = init_chat_model(model="gemini-2.5-flash" , model_provider="google_genai")

agent = create_agent(model , 
                     system_prompt="You are a fiction writer")

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept=".png" , multiple=False )

display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
import base64

uploaded_file = uploader.value[0]
content_mv = uploaded_file["content"]
img_bytes = bytes(content_mv)
img_b64 = base64.b64encode(img_bytes).decode("utf-8")
# Out:
# ...

# %%
from langchain.messages import HumanMessage

multimodal_question = HumanMessage(content=[
    {
        "type":"text" , "text" : "Tell me about the character in the image , and explain me the scene"
    } , 
    {
        "type" : "image" , "base64" : img_b64 , "mime_type" : "image/png"
    }
])

response = agent.invoke(
    {
        "messages" : [multimodal_question]
    }
)

print(response['messages'][-1].content)
# Out:
# This image captures a pivotal, intimate moment for a character on the precipice of a performance, a transformation, or perhaps, a confrontation.
#
# **The Character:**
#
# The character is **Saul Goodman**, or more accurately, **Jimmy McGill** in the process of fully embodying his alter-ego, Saul Goodman, a persona he uses to navigate the morally ambiguous world of law and crime. He's a man in his late 40s or early 50s, impeccably dressed in a dark pinstripe suit, a crisp white shirt, and a subtly striped tie. His hair is neatly combed, a testament to a meticulous attention to detail that often belies the chaos he orchestrates.
#
# His expression is a complex blend of weary intensity, fierce determination, and a touch of theatricality. There's a slight tightness around his mouth, a seriousness in his eyes that suggests the weight of whatever lies ahead. He's a man who has mastered the art of persuasion, manipulation, and turning disadvantages into opportunities. Beneath the slick exterior and the confident facade, there's a flicker of the earnest, struggling Jimmy McGill, but in this moment, he's steeling himself to be nothing but the unstoppable, charismatic force that is Saul. He's a showman, a con artist, and a brilliant, if morally compromised, lawyer.
#
# **The Scene:**
#
# The scene unfolds in a drab, utilitarian public restroom, a stark contrast to the sharp sophistication of the man's attire. The walls are lined with institutional grey tiles, and in the reflection, we can glimpse a scuffed, wooden stall door, suggesting a place of anonymity and transient use. The lighting is dim, almost noir-ish, casting shadows that emphasize the solitude and introspection of the moment.
#
# Saul stands before the mirror, not merely checking his appearance, but engaging in a profound ritual of self-preparation. His hands are splayed, palms facing the glass, mirroring the reflection's gesture. This isn't a casual pose; it's a dramatic flourish, a physical manifestation of psyching himself up. He's delivering a silent, intense pep talk to his reflection, to the man he needs to become in the next few moments.
#
# The words emblazoned at the bottom, **"IT'S SHOWTIME FOLKS,"** are not just a caption; they are the character's internal mantra, his battle cry. This is the moment before he steps onto his stage, whether that's a courtroom, a high-stakes negotiation, or a dangerous meeting. He's shedding any lingering doubts, any shred of his former, more earnest self, to fully embrace the confident, audacious, and somewhat theatrical persona of Saul Goodman. It's a moment of complete transformation, a deliberate act of putting on his "mask" before facing the world and delivering the performance of a lifetime. The grimy bathroom becomes his private dressing room, the mirror his audience, as he prepares to charm, persuade, or simply survive.
