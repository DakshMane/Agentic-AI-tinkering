# %% [markdown]
# Basic Prompting

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gemini-2.5-flash" , model_provider="google_genai" ,
                        temperature= 1.0 
                        )

response = model.invoke("What is capital of Moon ")

print(response.content)

# %%
## FEW SHOTS EXPLAINING IMPROVING PROMPTS

# %%
from dotenv import load_dotenv
load_dotenv()
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage

system_prompt = """
You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

sci_fi_agent = create_agent(
    model="gemini-2.5-flash" , 
    system_prompt=system_prompt

)

question = HumanMessage("What is the capital of Moon ? ")

response = sci_fi_agent.invoke({"messages" : [question]})

print(response["messages"][-1].contents)

# %%
from pydantic import BaseModel
from dotenv import load_dotenv
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage
from langchain.chat_models import init_chat_model

load_dotenv()

class ResultModel(BaseModel) :
    name : str 
    location : str 
    economy : str 
    vibe    : str 

system_prompt = """
You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""
model = init_chat_model(model="gemini-2.5-flash" , model_provider="google_genai" ,
                        temperature= 1.0 
                        )
sci_fi_agent = create_agent(
    model=model , 
    system_prompt=system_prompt , 
    

    response_format=ResultModel
)

question = HumanMessage("What is the capital of Moon ? ")

response = sci_fi_agent.invoke({"messages" : [question]})

print(response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 40
#      36 question = HumanMessage("What is the capital of Moon ? ")
#      37
#      38 response = sci_fi_agent.invoke({"messages" : [question]})
#      39
# ---> 40 print(response["messages"].contents)
#      41
#
# AttributeError: 'list' object has no attribute 'contents'
